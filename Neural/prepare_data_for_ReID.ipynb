# %%
import json
from pprint import pprint
Settings = json.load(open('../prototyping/settings.txt'))
pprint(Settings)
from pak.datasets.CUHK03 import cuhk03
from pak.datasets.Market1501 import Market1501
from CUHK03_Sampler import CUHK03_Sampler

sampler = CUHK03_Sampler()
# Out:
# {'data_root': '/Users/basheq/Desktop/RGBD_Lab/Data',
#  'deepmatch': '/Users/basheq/Desktop/RGBD_Lab/deepmatching_1.2.2_c++/deepmatching'}
# {'data_root': '/Users/basheq/Desktop/RGBD_Lab/Data',
#  'deepmatch': '/Users/basheq/Desktop/RGBD_Lab/deepmatching_1.2.2_c++/deepmatching'}
# unzip /Users/basheq/Desktop/RGBD_Lab/Data/cuhk03_release.zip -> /Users/basheq/Desktop/RGBD_Lab/Data
# cuhk03: view "labeled" 1/5
# cuhk03: view "labeled" 2/5
# cuhk03: view "labeled" 3/5
# cuhk03: view "labeled" 4/5
# cuhk03: view "labeled" 5/5
# positive test pairs: 9290
# positive train pairs: 127242

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

X_, Y_ = sampler.get_train_batch(5, 10)

idx = 8

A = X_[idx][:,:,0:3]
B = X_[idx][:,:,3:6]
print(Y_[idx])

print(A.shape, B.shape)
fig = plt.figure(figsize=(16,8))
fig.add_subplot(121).imshow(A)
fig.add_subplot(122).imshow(B)
plt.show()
# Out:
# [1 0]
# (112, 112, 3) (112, 112, 3)
